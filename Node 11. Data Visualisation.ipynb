# %% [markdown]
# ## 11-2. 파이썬으로 그래프를 그린다는건?

# %% [markdown]
# ### 파이썬으로 그래프를 그린다는 건?
# - 도화지를 펼치고 축을 그리고 그 안에 데이터를 그리는 작업

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")

# 보여주기
plt.savefig('./barplot.png')  # 그래프를 이미지로 출력
plt.show()                    # 그래프를 화면으로 출력

# %% [markdown]
# ## 11-3. 간단한 그래프 그리기 (1) 막대그래프 그려보기

# %% [markdown]
# ### 1. 데이터 정의

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# %% [markdown]
# ### 2. 축 그리기

# %%
# 축 그리기
fig = plt.figure() #도화지(그래프) 객체 생성
ax1 = fig.add_subplot(1,1,1) #figure()객체에 add_subplot 메서드를 이용해 축을 그려준다.

# %%
# 만약 축을 안 그린다면, figure 객체만 생성됨
fig = plt.figure()

# %%
# 축도 그리기
fig = plt.figure(figsize=(5,2))
ax1 = fig.add_subplot(1,1,1)

# %%
# 그래프 추가해보기
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

# %% [markdown]
# ### 3. 그래프 그리기

# %%
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject,points)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
ax.bar(subject, points)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ### 4. 그래프 요소 추가

# %%
# 그래프 데이터 
subject = ['English', 'Math', 'Korean', 'Science', 'Computer']
points = [40, 90, 50, 60, 100]

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
ax1.bar(subject, points)

# 라벨, 타이틀 달기
plt.xlabel('Subject')
plt.ylabel('Points')
plt.title("Yuna's Test Result")
# Out:
# Text(0.5, 1.0, "Yuna's Test Result")

# %%
fig, axs = plt.subplots(2,2, figsize=(8,6))
axs[0,0].bar(subject, points)

plt.xlabel('points')
plt.ylabel('subjects')

plt.show()

# %% [markdown]
# ## 11-4. 간단한 그래프 그리기 (2) 선 그래프 그려보기

# %%
from datetime import datetime
import pandas as pd
import os

# 그래프 데이터 
csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/AMZN.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
price = data['Close']

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
price.plot(ax=ax, style='black')
plt.ylim([1600,2200])
plt.xlim(['2019-05-01','2020-03-01'])

# 주석달기
important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
                xytext=(d,price.asof(d)+100), # 주석 텍스트가 위차할 좌표(x,y)
                arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %% [markdown]
# ### 윗 코드에서 주석 다는 부분 `for loop`말고 풀어서 해보기

# %%
from datetime import datetime
import pandas as pd
import os

# 그래프 데이터 
csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/AMZN.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
price = data['Close']

# 축 그리기 및 좌표축 설정
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
price.plot(ax=ax, style='black')
plt.ylim([1600,2200])
plt.xlim(['2019-05-01','2020-03-01'])

# DJ's version
ax.annotate("Low Price", (datetime(2019, 6, 3), price.asof(datetime(2019, 6, 3))+10),
           xytext=(datetime(2019, 6, 3), price.asof(datetime(2019,6,3))+100),
           arrowprops=dict(facecolor='red'))


# 주석달기
# important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]
# for d, label in important_data:
#     ax.annotate(label, xy=(d, price.asof(d)+10), # 주석을 달 좌표(x,y)
#                 xytext=(d,price.asof(d)+100), # 주석 텍스트가 위차할 좌표(x,y)
#                 arrowprops=dict(facecolor='red')) # 화살표 추가 및 색 설정

# 그리드, 타이틀 달기
plt.grid()
ax.set_title('StockPrice')

# 보여주기
plt.show()

# %% [markdown]
# ## 11-5. 간단한 그래프 그리기 (3) plot 사용법 상세

# %% [markdown]
# ### plt.plot()로 그래프 그리기

# %%
import numpy as np
x = np.linspace(0, 10, 100) #0에서 10까지 균등한 간격으로  100개의 숫자를 만들라는 뜻입니다.
plt.plot(x, np.sin(x),'o')
plt.plot(x, np.cos(x),'--', color='black') 
plt.show()

# %%
x = np.linspace(0, 10, 100) 

plt.subplot(2,1,1)
plt.plot(x, np.sin(x),'orange','o')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange') 
plt.show()

# %%
plt.subplot(2,1,1)
plt.plot(x, np.sin(x), 'red', 'o')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange')
plt.show()

# %% [markdown]
# ### linestyle, marker 옵션

# %%
x = np.linspace(0, 10, 100) 

plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# ### Pandas로 그래프 그리기

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %% [markdown]
# ## 11-7. 그래프 4대 천왕 (1) 데이터 준비

# %% [markdown]
# ### 1) 데이터 불러오기

# %%
import pandas as pd
import seaborn as sns

tips = sns.load_dataset("tips")

# %% [markdown]
# ### 2) 데이터 살펴보기 (EDA)

# %%
df = pd.DataFrame(tips)
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# categorical columns의 데이터 확인
categories = ['sex', 'smoker', 'day', 'time', 'size']

for col in categories:
    print(df[col].value_counts())
    print('===========================')
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64
# ===========================
# No     151
# Yes     93
# Name: smoker, dtype: int64
# ===========================
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64
# ===========================
# Dinner    176
# Lunch      68
# Name: time, dtype: int64
# ===========================
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64
# ===========================

# %% [markdown]
# ## 11-8. 그래프 4대 천왕 (2) 범주형 데이터
#
# - 변수 데이터를 시각화할 때 데이터 종류에 따라 사용하는 그래프가 다르다는 걸 알고 계시나요?
# - 지금부터 범주형, 수치형 순으로 총 4개의 그래프를 살펴보겠습니다

# %% [markdown]
# ### 범주형 데이터

# %% [markdown]
# #### 1) 막대그래프(bar graph)
# - matplotlib에 데이터를 인자로 넣기 위해선 pandas 데이터를 바로 이용할 수는 없습니다.
# - 데이터를 x에 series 또는 list, y에 list 형태로 각각 나눠주어야 합니다.

# %%
# groupby 쓰기
grouped = df['tip'].groupby(df['sex'])

# %%
grouped.mean() # 성별에 따른 팁의 평균
# Out:
# sex
# Male      3.089618
# Female    2.833448
# Name: tip, dtype: float64

# %%
grouped.size() # 성별에 따른 데이터 량(팁 횟수)
# Out:
# sex
# Male      157
# Female     87
# Name: tip, dtype: int64

# %%
import numpy as np
sex = dict(grouped.mean()) #평균 데이터를 딕셔너리 형태로 바꿔줍니다.
sex
# Out:
# {'Male': 3.0896178343949052, 'Female': 2.833448275862069}

# %%
x = list(sex.keys())  
x
# Out:
# ['Male', 'Female']

# %%
y = list(sex.values())
y
# Out:
# [3.0896178343949052, 2.833448275862069]

# %%
import matplotlib.pyplot as plt

plt.bar(x=x, height=y)
plt.ylabel('tip[$]')
plt.title('Tip by Sex')
# Out:
# Text(0.5, 1.0, 'Tip by Sex')

# %%
# DJ's practice

plt.bar(x=df['sex'], height=df['tip'])

# 왜 다른가 살펴봤더니, 그냥 정제되지 않은 컬럼을 넣으면 df['tip'].groupby(df['sex']).max() 가 나온다.
# Out:
# <BarContainer object of 244 artists>

# %% [markdown]
# ### 1) - 2 Seaborn과 Matplotlib을 활용한 간단한 방법

# %%
# seaborn은 알아서 평균을 넣어 줌...
sns.barplot(data=df, x='sex', y='tip')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
# Matplotlib을 통해 다양한 요소도 넣어줄 수 있음
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='sex', y='tip')
plt.ylim(0,4)
plt.title('Tip by Sex')
# Out:
# Text(0.5, 1.0, 'Tip by Sex')

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=df, x='day', y='tip')
plt.ylim(0,4)
plt.title('Tip by Day')
# Out:
# Text(0.5, 1.0, 'Tip by Day')

# %%
# violin plot도 사용

fig = plt.figure(figsize=(10,7))

ax1 = fig.add_subplot(2,2,1)
sns.barplot(data=df, x='day', y='tip',palette="ch:.25")

ax2 = fig.add_subplot(2,2,2)
sns.barplot(data=df, x='sex', y='tip')

ax3 = fig.add_subplot(2,2,4)
sns.violinplot(data=df, x='sex', y='tip')

ax4 = fig.add_subplot(2,2,3)
sns.violinplot(data=df, x='day', y='tip',palette="ch:.25")
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
# catplot 사용
sns.catplot(x="day", y="tip", jitter=False, data=tips)

# %% [markdown]
# ### 11-9. 그래프 4대 천왕 (3) 수치형 데이터

# %% [markdown]
# ### 수치형 데이터
# - scatter
# - line
# - `total bill`에 따른 `tip` 데이터 그려보기

# %% [markdown]
# #### 2) 산점도(scatter plot)

# %%
sns.scatterplot(data=df , x='total_bill', y='tip', palette="ch:r=-.2,d=.3_r")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
# hue로 다른 컬럼 넣어서 색깔 구분 가능
sns.scatterplot(data=df, x='total_bill', y='tip', hue='day')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 3) 선 그래프(line graph)
# - tips 예제로는 선 그래프 그리기 어려워서 numpy로 데이터 생성 후 설명

# %%
#np.random.randn 함수는 표준 정규분포에서 난수를 생성하는 함수입니다. 
#cumsum()은 누적합을 구하는 함수입니다.
plt.plot(np.random.randn(50).cumsum())

# %%
# 과연 라인그래프로 해보면 어떨지 실험했는데, 역시 아님...

plt.plot(df['total_bill'], df['tip'])

# %%
# 얘도 선그래프. plot은 default로 line임

x = np.linspace(0, 10, 100) 
plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x)) 
plt.show()

# %%
# seaborn 이용
sns.lineplot(x=x, y=np.sin(x))
sns.lineplot(x=x, y=np.cos(x))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4) 히스토그램
# - 다음과 같이 만들어 보기
# - x1은 평균은 100이고 표준편차는 15인 정규분포를 따릅니다.
# - x2는 평균은 130이고 표준편차는 15인 정규분포를 따릅니다.
# - 도수를 50개의 구간으로 표시하며, 확률 밀도가 아닌 빈도로 표기합니다.

# %%
#그래프 데이터 
mu1, mu2, sigma = 100, 130, 15
x1 = mu1 + sigma*np.random.randn(10000)
x2 = mu2 + sigma*np.random.randn(10000)

# 축 그리기
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# 그래프 그리기
patches = ax1.hist(x1, bins=50, density=False) #bins는 x값을 총 50개 구간으로 나눈다는 뜻입니다.
patches = ax1.hist(x2, bins=50, density=False, alpha=0.5)
ax1.xaxis.set_ticks_position('bottom') # x축의 눈금을 아래 표시 
ax1.yaxis.set_ticks_position('left') #y축의 눈금을 왼쪽에 표시

# 라벨, 타이틀 달기
plt.xlabel('Bins')
plt.ylabel('Number of Values in Bin')
ax1.set_title('Two Frequency Distributions')

# 보여주기
plt.show()

# %% [markdown]
# ### 예제 데이터의 히스토그램

# %%
sns.histplot(df['total_bill'], label='total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(df['total_bill'], label='total_bill')
sns.histplot(df['tip'], label='tip').legend() # legend()를 이용하여 label을 표시해 줍니다.

# %%
df['tip_pct'] = df['tip'] / df['total_bill']
df['tip_pct'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df[df['tip_pct'] > 0.7]
# Out:
#      total_bill   tip   sex smoker  day    time  size   tip_pct
# 172        7.25  5.15  Male    Yes  Sun  Dinner     2  0.710345

# %%
df['tip_pct'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# ## 11-10. 시계열 데이터 시각화하기

# %% [markdown]
# ### 1. 데이터 가져오기

# %%
csv_path = os.getenv("HOME") + "/aiffel/data_visualization/data/flights.csv"
data = pd.read_csv(csv_path)
flights = pd.DataFrame(data)
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
# seaborn load_dataset으로 갖고 와보기
sns.load_dataset('flights').head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# ### 2. 그래프 그리기

# %%
sns.barplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.pointplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.scatterplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights, x='year', y='passengers')
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
# 달별로 보기 위해 hue에 month 넣어줌
sns.lineplot(data=flights, x='year', y='passengers', hue='month', palette='ch:.50')
plt.legend(bbox_to_anchor=(1.03, 1), loc=2) #legend 그래프 밖에 추가하기

# %% [markdown]
# ### 히스토그램

# %%
sns.histplot(flights['passengers'])
# Out:
# <AxesSubplot:xlabel='passengers', ylabel='Count'>

# %% [markdown]
# ## 11-11. Heatmap
# - Heatmap은 방대한 양의 데이터와 현상을 수치에 따른 색상으로 나타내는 것으로,
# -데이터 차원에 대한 제한은 없으나 모두 2차원으로 시각화하여 표현합니다.

# %%
pivot = flights.pivot(index='year', columns='month', values='passengers')
pivot
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
# 1954     227     293       229       188      204   302   264    235  234
# 1955     269     347       278       233      242   364   315    267  270
# 1956     313     405       306       277      284   413   374    317  318
# 1957     348     467       336       301      315   465   422    356  355
# 1958     348     505       337       318      340   491   435    362  363
# 1959     396     559       405       342      360   548   472    406  420
# 1960     461     606       432       391      417   622   535    419  472
#
# month  November  October  September
# year
# 1949        104      119        136
# 1950        114      133        158
# 1951        146      162        184
# 1952        172      191        209
# 1953        180      211        237
# 1954        203      229        259
# 1955        237      274        312
# 1956        271      306        355
# 1957        305      347        404
# 1958        310      359        404
# 1959        362      407        463
# 1960        390      461        508

# %%
sns.heatmap(pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights['month'][:12]
# Out:
# 0       January
# 1      February
# 2         March
# 3         April
# 4           May
# 5          June
# 6          July
# 7        August
# 8     September
# 9       October
# 10     November
# 11     December
# Name: month, dtype: object

# %%
# month를 알파벳 순 말고 월별 순으로 다시 해보기
# pivot(columns=에는 컬럼명이 꼭 들어가야함. 컬럼의 내용이 아니라)


new_pivot = flights.pivot(index='year', columns='month', values='passengers')
new_pivot
# Out:
# month  April  August  December  February  January  July  June  March  May  \
# year
# 1949     129     148       118       118      112   148   135    132  121
# 1950     135     170       140       126      115   170   149    141  125
# 1951     163     199       166       150      145   199   178    178  172
# 1952     181     242       194       180      171   230   218    193  183
# 1953     235     272       201       196      196   264   243    236  229
# 1954     227     293       229       188      204   302   264    235  234
# 1955     269     347       278       233      242   364   315    267  270
# 1956     313     405       306       277      284   413   374    317  318
# 1957     348     467       336       301      315   465   422    356  355
# 1958     348     505       337       318      340   491   435    362  363
# 1959     396     559       405       342      360   548   472    406  420
# 1960     461     606       432       391      417   622   535    419  472
#
# month  November  October  September
# year
# 1949        104      119        136
# 1950        114      133        158
# 1951        146      162        184
# 1952        172      191        209
# 1953        180      211        237
# 1954        203      229        259
# 1955        237      274        312
# 1956        271      306        355
# 1957        305      347        404
# 1958        310      359        404
# 1959        362      407        463
# 1960        390      461        508

# %%
sns.heatmap(pivot, linewidths=.2, annot=True, fmt="d")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
sns.heatmap(pivot, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
